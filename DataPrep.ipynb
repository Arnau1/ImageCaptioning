# %%
# Required packages
import pandas as pd
import numpy as np

# %%
# Import functions
from data_processing import *

# %% [markdown]
# ### Load data

# %%
info = pd.read_csv('info.csv', index_col=0)
info.drop('Ingredients', axis=1, inplace=True) # Drop ingredients since we will use the ´Cleaned_Ingredients´ strings
info.dropna(inplace=True) # Drop null values

# %%
info.head()
# Out:
#                                                Title  \
# 0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1                    Crispy Salt and Pepper Potatoes
# 2                        Thanksgiving Mac and Cheese
# 3                 Italian Sausage and Bread Stuffing
# 4                                       Newton's Law
#
#                                         Instructions  \
# 0  Pat chicken dry with paper towels, season all ...
# 1  Preheat oven to 400°F and line a rimmed baking...
# 2  Place a rack in middle of oven; preheat to 400...
# 3  Preheat oven to 350°F with rack in middle. Gen...
# 4  Stir together brown sugar and hot water in a c...
#
#                                           Image_Name  \
# 0  miso-butter-roast-chicken-acorn-squash-panzanella
# 1         crispy-salt-and-pepper-potatoes-dan-kluger
# 2         thanksgiving-mac-and-cheese-erick-williams
# 3          italian-sausage-and-bread-stuffing-240559
# 4                 newtons-law-apple-bourbon-cocktail
#
#                                  Cleaned_Ingredients
# 0  ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1  ['2 large egg whites', '1 pound new potatoes (...
# 2  ['1 cup evaporated milk', '1 cup whole milk', ...
# 3  ['1 (¾- to 1-pound) round Italian loaf, cut in...
# 4  ['1 teaspoon dark brown sugar', '1 teaspoon ho...

# %%
info.describe() # We can see null image names are called ´#NAME?´
# Out:
#                 Title                                       Instructions  \
# count           13493                                              13493
# unique          13302                                              13464
# top     Potato Latkes  Place ingredients in blender in the order list...
# freq                5                                                  5
#
#        Image_Name Cleaned_Ingredients
# count       13493               13493
# unique      13464               13471
# top        #NAME?                ['']
# freq           30                   6

# %%
info = info[info['Image_Name'] != '#NAME?'] # Drop null image names

# %%
info.describe()
# Out:
#             Title                                       Instructions  \
# count       13463                                              13463
# unique      13273                                              13434
# top     French 75  Place ingredients in blender in the order list...
# freq            5                                                  5
#
#                                                Image_Name Cleaned_Ingredients
# count                                               13463               13463
# unique                                              13463               13441
# top     miso-butter-roast-chicken-acorn-squash-panzanella                ['']
# freq                                                    1                   6

# %% [markdown]
# ### Statistical analysis

# %% [markdown]
# #### Images analysis

# %%
# Analyze the dimensions of images
folder = 'Food Images'

look_images(info, folder)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Analyze the dimensions of images
#       2 folder = 'Food Images'
# ----> 4 look_images(info, folder)
#
# File d:\Image Captioning\data_processing.py:42, in look_images(dataframe, folder, column, extension)
#      40 image_path = os.path.join(folder, image_name + extension)
#      41 try:
# ---> 42     with Image.open(image_path) as img:
#      43         width, height = img.size  # Get image dimensions
#      44         widths.append(width)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\PIL\Image.py:3218, in open(fp, mode, formats)
#    3215     filename = fp
#    3217 if filename:
# -> 3218     fp = builtins.open(filename, "rb")
#    3219     exclusive_fp = True
#    3221 try:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Titles analysis

# %%
# Analyze strings
lengths = info['Title'].str.len()
print("Title lengths:")
print(f"Longest title: {max(lengths)} characters.")
print(f"Shortest title: {min(lengths)} characters.")
print(f"Mean title length: {round(np.mean(lengths),2)} characters.")
print(f"Standard Deviation of title lengths: {round(np.std(lengths),2)} characters.")
# Out:
# Title lengths:
# Longest title: 112 characters.
# Shortest title: 3 characters.
# Mean title length: 32.75 characters.
# Standard Deviation of title lengths: 14.76 characters.

# %%
# Analyze characters
look_char(info, 'Title')
# Out:
# Unique characters: 136
#
#  !"#%&'()+,-./012345679:;ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz ®ÁÉàáâãäçèéêëìíîïñòóôöøùúûüōờ́̃̉Сикнры –—‘’“”강개닭된장전정찌파
#
# Character: <control>
# Appearances: 3
#
# Character: SPACE
# Appearances: 13255
#
# Character: EXCLAMATION MARK
# Appearances: 1
#
# Character: QUOTATION MARK
# Appearances: 101
#
# Character: NUMBER SIGN
# Appearances: 1
#
# Character: PERCENT SIGN
# Appearances: 1
#
# Character: AMPERSAND
# Appearances: 81
#
# Character: APOSTROPHE
# Appearances: 330
#
# Character: LEFT PARENTHESIS
# Appearances: 294
#
# Character: RIGHT PARENTHESIS
# Appearances: 294
#
# Character: PLUS SIGN
# Appearances: 2
#
# Character: COMMA
# Appearances: 1030
#
# Character: HYPHEN-MINUS
# Appearances: 3152
#
# Character: FULL STOP
# Appearances: 25
#
# Character: SOLIDUS
# Appearances: 6
#
# Character: DIGIT ZERO
# Appearances: 10
#
# Character: DIGIT ONE
# Appearances: 18
#
# Character: DIGIT TWO
# Appearances: 15
#
# Character: DIGIT THREE
# Appearances: 76
#
# Character: DIGIT FOUR
# Appearances: 6
#
# Character: DIGIT FIVE
# Appearances: 21
#
# Character: DIGIT SIX
# Appearances: 3
#
# Character: DIGIT SEVEN
# Appearances: 10
#
# Character: DIGIT NINE
# Appearances: 1
#
# Character: COLON
# Appearances: 17
#
# Character: SEMICOLON
# Appearances: 2
#
# Character: LATIN CAPITAL LETTER A
# Appearances: 1617
#
# Character: LATIN CAPITAL LETTER B
# Appearances: 4356
#
# Character: LATIN CAPITAL LETTER C
# Appearances: 7060
#
# Character: LATIN CAPITAL LETTER D
# Appearances: 1127
#
# Character: LATIN CAPITAL LETTER E
# Appearances: 735
#
# Character: LATIN CAPITAL LETTER F
# Appearances: 2162
#
# Character: LATIN CAPITAL LETTER G
# Appearances: 2750
#
# Character: LATIN CAPITAL LETTER H
# Appearances: 1331
#
# Character: LATIN CAPITAL LETTER I
# Appearances: 544
#
# Character: LATIN CAPITAL LETTER J
# Appearances: 312
#
# Character: LATIN CAPITAL LETTER K
# Appearances: 399
#
# Character: LATIN CAPITAL LETTER L
# Appearances: 1630
#
# Character: LATIN CAPITAL LETTER M
# Appearances: 2538
#
# Character: LATIN CAPITAL LETTER N
# Appearances: 503
#
# Character: LATIN CAPITAL LETTER O
# Appearances: 1166
#
# Character: LATIN CAPITAL LETTER P
# Appearances: 4837
#
# Character: LATIN CAPITAL LETTER Q
# Appearances: 208
#
# Character: LATIN CAPITAL LETTER R
# Appearances: 2743
#
# Character: LATIN CAPITAL LETTER S
# Appearances: 6795
#
# Character: LATIN CAPITAL LETTER T
# Appearances: 2691
#
# Character: LATIN CAPITAL LETTER U
# Appearances: 100
#
# Character: LATIN CAPITAL LETTER V
# Appearances: 804
#
# Character: LATIN CAPITAL LETTER W
# Appearances: 1573
#
# Character: LATIN CAPITAL LETTER X
# Appearances: 5
#
# Character: LATIN CAPITAL LETTER Y
# Appearances: 307
#
# Character: LATIN CAPITAL LETTER Z
# Appearances: 171
#
# Character: LATIN SMALL LETTER A
# Appearances: 12251
#
# Character: LATIN SMALL LETTER B
# Appearances: 2979
#
# Character: LATIN SMALL LETTER C
# Appearances: 7300
#
# Character: LATIN SMALL LETTER D
# Appearances: 8890
#
# Character: LATIN SMALL LETTER E
# Appearances: 12587
#
# Character: LATIN SMALL LETTER F
# Appearances: 1617
#
# Character: LATIN SMALL LETTER G
# Appearances: 4175
#
# Character: LATIN SMALL LETTER H
# Appearances: 9047
#
# Character: LATIN SMALL LETTER I
# Appearances: 11325
#
# Character: LATIN SMALL LETTER J
# Appearances: 123
#
# Character: LATIN SMALL LETTER K
# Appearances: 4844
#
# Character: LATIN SMALL LETTER L
# Appearances: 9091
#
# Character: LATIN SMALL LETTER M
# Appearances: 5719
#
# Character: LATIN SMALL LETTER N
# Appearances: 10474
#
# Character: LATIN SMALL LETTER O
# Appearances: 10350
#
# Character: LATIN SMALL LETTER P
# Appearances: 4684
#
# Character: LATIN SMALL LETTER Q
# Appearances: 356
#
# Character: LATIN SMALL LETTER R
# Appearances: 10944
#
# Character: LATIN SMALL LETTER S
# Appearances: 9695
#
# Character: LATIN SMALL LETTER T
# Appearances: 10485
#
# Character: LATIN SMALL LETTER U
# Appearances: 7453
#
# Character: LATIN SMALL LETTER V
# Appearances: 1125
#
# Character: LATIN SMALL LETTER W
# Appearances: 5856
#
# Character: LATIN SMALL LETTER X
# Appearances: 231
#
# Character: LATIN SMALL LETTER Y
# Appearances: 3570
#
# Character: LATIN SMALL LETTER Z
# Appearances: 984
#
# Character: <control>
# Appearances: 1
#
# Character: <control>
# Appearances: 5
#
# Character: NO-BREAK SPACE
# Appearances: 2
#
# Character: REGISTERED SIGN
# Appearances: 2
#
# Character: LATIN CAPITAL LETTER A WITH ACUTE
# Appearances: 5
#
# Character: LATIN CAPITAL LETTER E WITH ACUTE
# Appearances: 1
#
# Character: LATIN SMALL LETTER A WITH GRAVE
# Appearances: 20
#
# Character: LATIN SMALL LETTER A WITH ACUTE
# Appearances: 8
#
# Character: LATIN SMALL LETTER A WITH CIRCUMFLEX
# Appearances: 22
#
# Character: LATIN SMALL LETTER A WITH TILDE
# Appearances: 1
#
# Character: LATIN SMALL LETTER A WITH DIAERESIS
# Appearances: 2
#
# Character: LATIN SMALL LETTER C WITH CEDILLA
# Appearances: 23
#
# Character: LATIN SMALL LETTER E WITH GRAVE
# Appearances: 117
#
# Character: LATIN SMALL LETTER E WITH ACUTE
# Appearances: 271
#
# Character: LATIN SMALL LETTER E WITH CIRCUMFLEX
# Appearances: 8
#
# Character: LATIN SMALL LETTER E WITH DIAERESIS
# Appearances: 5
#
# Character: LATIN SMALL LETTER I WITH GRAVE
# Appearances: 1
#
# Character: LATIN SMALL LETTER I WITH ACUTE
# Appearances: 14
#
# Character: LATIN SMALL LETTER I WITH CIRCUMFLEX
# Appearances: 57
#
# Character: LATIN SMALL LETTER I WITH DIAERESIS
# Appearances: 13
#
# Character: LATIN SMALL LETTER N WITH TILDE
# Appearances: 44
#
# Character: LATIN SMALL LETTER O WITH GRAVE
# Appearances: 1
#
# Character: LATIN SMALL LETTER O WITH ACUTE
# Appearances: 15
#
# Character: LATIN SMALL LETTER O WITH CIRCUMFLEX
# Appearances: 4
#
# Character: LATIN SMALL LETTER O WITH DIAERESIS
# Appearances: 8
#
# Character: LATIN SMALL LETTER O WITH STROKE
# Appearances: 1
#
# Character: LATIN SMALL LETTER U WITH GRAVE
# Appearances: 28
#
# Character: LATIN SMALL LETTER U WITH ACUTE
# Appearances: 3
#
# Character: LATIN SMALL LETTER U WITH CIRCUMFLEX
# Appearances: 29
#
# Character: LATIN SMALL LETTER U WITH DIAERESIS
# Appearances: 3
#
# Character: LATIN SMALL LETTER O WITH MACRON
# Appearances: 1
#
# Character: LATIN SMALL LETTER O WITH HORN
# Appearances: 1
#
# Character: COMBINING GRAVE ACCENT
# Appearances: 1
#
# Character: COMBINING ACUTE ACCENT
# Appearances: 2
#
# Character: COMBINING TILDE
# Appearances: 1
#
# Character: COMBINING HOOK ABOVE
# Appearances: 1
#
# Character: CYRILLIC CAPITAL LETTER ES
# Appearances: 1
#
# Character: CYRILLIC SMALL LETTER I
# Appearances: 1
#
# Character: CYRILLIC SMALL LETTER KA
# Appearances: 1
#
# Character: CYRILLIC SMALL LETTER EN
# Appearances: 1
#
# Character: CYRILLIC SMALL LETTER ER
# Appearances: 1
#
# Character: CYRILLIC SMALL LETTER YERU
# Appearances: 1
#
# Character: THIN SPACE
# Appearances: 1
#
# Character: EN DASH
# Appearances: 85
#
# Character: EM DASH
# Appearances: 3
#
# Character: LEFT SINGLE QUOTATION MARK
# Appearances: 2
#
# Character: RIGHT SINGLE QUOTATION MARK
# Appearances: 27
#
# Character: LEFT DOUBLE QUOTATION MARK
# Appearances: 9
#
# Character: RIGHT DOUBLE QUOTATION MARK
# Appearances: 9
#
# Character: HANGUL SYLLABLE GANG
# Appearances: 1
#
# Character: HANGUL SYLLABLE GAE
# Appearances: 1
#
# Character: HANGUL SYLLABLE DALG
# Appearances: 1
#
# Character: HANGUL SYLLABLE DOEN
# Appearances: 1
#
# Character: HANGUL SYLLABLE JANG
# Appearances: 1
#
# Character: HANGUL SYLLABLE JEON
# Appearances: 1
#
# Character: HANGUL SYLLABLE JEONG
# Appearances: 1
#
# Character: HANGUL SYLLABLE JJI
# Appearances: 1
#
# Character: HANGUL SYLLABLE PA
# Appearances: 1

# %% [markdown]
# #### Ingredients analysis

# %%
# Analyze strings
lengths = info['Cleaned_Ingredients'].str.len()
print("Ingredients lengths:")
print(f"Longest ingredient list: {max(lengths)} characters.")
print(f"Shortest ingredient list: {min(lengths)} characters.")
print(f"Mean ingredient list length: {round(np.mean(lengths),2)} characters.")
print(f"Standard Deviation of ingredient list lengths: {round(np.std(lengths),2)} characters.")
# Out:
# Ingredients lengths:
# Longest ingredient list: 2379 characters.
# Shortest ingredient list: 4 characters.
# Mean ingredient list length: 419.14 characters.
# Standard Deviation of ingredient list lengths: 202.22 characters.

# %%
# Analyze characters
look_char(info, 'Cleaned_Ingredients')
# Out:
# Unique characters: 147
#  !"#%&'()*+,-./0123456789:;<=>@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]_abcdefghijklmnopqrstuvwxyz{|}®°¼½¾¿ÁÉ×àáâäåçèéêëìíîïñóôõùúûüōź̀́̂‐‑–—’‚“”•″⁄™⅓⅔⅛⅜⅞ﬀﬁﬂ�
#
# Character: SPACE
# Appearances: 13457
#
# Character: EXCLAMATION MARK
# Appearances: 9
#
# Character: QUOTATION MARK
# Appearances: 1879
#
# Character: NUMBER SIGN
# Appearances: 10
#
# Character: PERCENT SIGN
# Appearances: 276
#
# Character: AMPERSAND
# Appearances: 31
#
# Character: APOSTROPHE
# Appearances: 13463
#
# Character: LEFT PARENTHESIS
# Appearances: 10724
#
# Character: RIGHT PARENTHESIS
# Appearances: 10721
#
# Character: ASTERISK
# Appearances: 681
#
# Character: PLUS SIGN
# Appearances: 9
#
# Character: COMMA
# Appearances: 13436
#
# Character: HYPHEN-MINUS
# Appearances: 10184
#
# Character: FULL STOP
# Appearances: 1864
#
# Character: SOLIDUS
# Appearances: 12161
#
# Character: DIGIT ZERO
# Appearances: 2446
#
# Character: DIGIT ONE
# Appearances: 13244
#
# Character: DIGIT TWO
# Appearances: 13002
#
# Character: DIGIT THREE
# Appearances: 9807
#
# Character: DIGIT FOUR
# Appearances: 11162
#
# Character: DIGIT FIVE
# Appearances: 3469
#
# Character: DIGIT SIX
# Appearances: 4608
#
# Character: DIGIT SEVEN
# Appearances: 1289
#
# Character: DIGIT EIGHT
# Appearances: 4186
#
# Character: DIGIT NINE
# Appearances: 871
#
# Character: COLON
# Appearances: 1154
#
# Character: SEMICOLON
# Appearances: 1525
#
# Character: LESS-THAN SIGN
# Appearances: 25
#
# Character: EQUALS SIGN
# Appearances: 5
#
# Character: GREATER-THAN SIGN
# Appearances: 28
#
# Character: COMMERCIAL AT
# Appearances: 1
#
# Character: LATIN CAPITAL LETTER A
# Appearances: 2196
#
# Character: LATIN CAPITAL LETTER B
# Appearances: 1207
#
# Character: LATIN CAPITAL LETTER C
# Appearances: 2571
#
# Character: LATIN CAPITAL LETTER D
# Appearances: 1106
#
# Character: LATIN CAPITAL LETTER E
# Appearances: 867
#
# Character: LATIN CAPITAL LETTER F
# Appearances: 2106
#
# Character: LATIN CAPITAL LETTER G
# Appearances: 1826
#
# Character: LATIN CAPITAL LETTER H
# Appearances: 549
#
# Character: LATIN CAPITAL LETTER I
# Appearances: 1222
#
# Character: LATIN CAPITAL LETTER J
# Appearances: 647
#
# Character: LATIN CAPITAL LETTER K
# Appearances: 2237
#
# Character: LATIN CAPITAL LETTER L
# Appearances: 915
#
# Character: LATIN CAPITAL LETTER M
# Appearances: 1363
#
# Character: LATIN CAPITAL LETTER N
# Appearances: 818
#
# Character: LATIN CAPITAL LETTER O
# Appearances: 627
#
# Character: LATIN CAPITAL LETTER P
# Appearances: 2682
#
# Character: LATIN CAPITAL LETTER Q
# Appearances: 33
#
# Character: LATIN CAPITAL LETTER R
# Appearances: 816
#
# Character: LATIN CAPITAL LETTER S
# Appearances: 2730
#
# Character: LATIN CAPITAL LETTER T
# Appearances: 1880
#
# Character: LATIN CAPITAL LETTER U
# Appearances: 125
#
# Character: LATIN CAPITAL LETTER V
# Appearances: 707
#
# Character: LATIN CAPITAL LETTER W
# Appearances: 483
#
# Character: LATIN CAPITAL LETTER X
# Appearances: 11
#
# Character: LATIN CAPITAL LETTER Y
# Appearances: 334
#
# Character: LATIN CAPITAL LETTER Z
# Appearances: 154
#
# Character: LEFT SQUARE BRACKET
# Appearances: 13463
#
# Character: REVERSE SOLIDUS
# Appearances: 15
#
# Character: RIGHT SQUARE BRACKET
# Appearances: 13463
#
# Character: LOW LINE
# Appearances: 2
#
# Character: LATIN SMALL LETTER A
# Appearances: 13449
#
# Character: LATIN SMALL LETTER B
# Appearances: 13140
#
# Character: LATIN SMALL LETTER C
# Appearances: 13417
#
# Character: LATIN SMALL LETTER D
# Appearances: 13295
#
# Character: LATIN SMALL LETTER E
# Appearances: 13455
#
# Character: LATIN SMALL LETTER F
# Appearances: 12560
#
# Character: LATIN SMALL LETTER G
# Appearances: 13186
#
# Character: LATIN SMALL LETTER H
# Appearances: 13242
#
# Character: LATIN SMALL LETTER I
# Appearances: 13423
#
# Character: LATIN SMALL LETTER J
# Appearances: 5098
#
# Character: LATIN SMALL LETTER K
# Appearances: 12010
#
# Character: LATIN SMALL LETTER L
# Appearances: 13417
#
# Character: LATIN SMALL LETTER M
# Appearances: 13059
#
# Character: LATIN SMALL LETTER N
# Appearances: 13430
#
# Character: LATIN SMALL LETTER O
# Appearances: 13437
#
# Character: LATIN SMALL LETTER P
# Appearances: 13386
#
# Character: LATIN SMALL LETTER Q
# Appearances: 2857
#
# Character: LATIN SMALL LETTER R
# Appearances: 13448
#
# Character: LATIN SMALL LETTER S
# Appearances: 13452
#
# Character: LATIN SMALL LETTER T
# Appearances: 13414
#
# Character: LATIN SMALL LETTER U
# Appearances: 13416
#
# Character: LATIN SMALL LETTER V
# Appearances: 11832
#
# Character: LATIN SMALL LETTER W
# Appearances: 11368
#
# Character: LATIN SMALL LETTER X
# Appearances: 4835
#
# Character: LATIN SMALL LETTER Y
# Appearances: 12095
#
# Character: LATIN SMALL LETTER Z
# Appearances: 4571
#
# Character: LEFT CURLY BRACKET
# Appearances: 3
#
# Character: VERTICAL LINE
# Appearances: 4
#
# Character: RIGHT CURLY BRACKET
# Appearances: 3
#
# Character: REGISTERED SIGN
# Appearances: 8
#
# Character: DEGREE SIGN
# Appearances: 104
#
# Character: VULGAR FRACTION ONE QUARTER
# Appearances: 257
#
# Character: VULGAR FRACTION ONE HALF
# Appearances: 395
#
# Character: VULGAR FRACTION THREE QUARTERS
# Appearances: 148
#
# Character: INVERTED QUESTION MARK
# Appearances: 1
#
# Character: LATIN CAPITAL LETTER A WITH ACUTE
# Appearances: 2
#
# Character: LATIN CAPITAL LETTER E WITH ACUTE
# Appearances: 1
#
# Character: MULTIPLICATION SIGN
# Appearances: 3
#
# Character: LATIN SMALL LETTER A WITH GRAVE
# Appearances: 7
#
# Character: LATIN SMALL LETTER A WITH ACUTE
# Appearances: 102
#
# Character: LATIN SMALL LETTER A WITH CIRCUMFLEX
# Appearances: 30
#
# Character: LATIN SMALL LETTER A WITH DIAERESIS
# Appearances: 6
#
# Character: LATIN SMALL LETTER A WITH RING ABOVE
# Appearances: 1
#
# Character: LATIN SMALL LETTER C WITH CEDILLA
# Appearances: 52
#
# Character: LATIN SMALL LETTER E WITH GRAVE
# Appearances: 398
#
# Character: LATIN SMALL LETTER E WITH ACUTE
# Appearances: 271
#
# Character: LATIN SMALL LETTER E WITH CIRCUMFLEX
# Appearances: 4
#
# Character: LATIN SMALL LETTER E WITH DIAERESIS
# Appearances: 1
#
# Character: LATIN SMALL LETTER I WITH GRAVE
# Appearances: 2
#
# Character: LATIN SMALL LETTER I WITH ACUTE
# Appearances: 26
#
# Character: LATIN SMALL LETTER I WITH CIRCUMFLEX
# Appearances: 235
#
# Character: LATIN SMALL LETTER I WITH DIAERESIS
# Appearances: 3
#
# Character: LATIN SMALL LETTER N WITH TILDE
# Appearances: 443
#
# Character: LATIN SMALL LETTER O WITH ACUTE
# Appearances: 54
#
# Character: LATIN SMALL LETTER O WITH CIRCUMFLEX
# Appearances: 8
#
# Character: LATIN SMALL LETTER O WITH TILDE
# Appearances: 1
#
# Character: LATIN SMALL LETTER U WITH GRAVE
# Appearances: 1
#
# Character: LATIN SMALL LETTER U WITH ACUTE
# Appearances: 15
#
# Character: LATIN SMALL LETTER U WITH CIRCUMFLEX
# Appearances: 5
#
# Character: LATIN SMALL LETTER U WITH DIAERESIS
# Appearances: 7
#
# Character: LATIN SMALL LETTER O WITH MACRON
# Appearances: 1
#
# Character: LATIN SMALL LETTER Z WITH ACUTE
# Appearances: 1
#
# Character: COMBINING GRAVE ACCENT
# Appearances: 1
#
# Character: COMBINING ACUTE ACCENT
# Appearances: 4
#
# Character: COMBINING CIRCUMFLEX ACCENT
# Appearances: 1
#
# Character: HYPHEN
# Appearances: 1
#
# Character: NON-BREAKING HYPHEN
# Appearances: 1
#
# Character: EN DASH
# Appearances: 478
#
# Character: EM DASH
# Appearances: 34
#
# Character: RIGHT SINGLE QUOTATION MARK
# Appearances: 108
#
# Character: SINGLE LOW-9 QUOTATION MARK
# Appearances: 1
#
# Character: LEFT DOUBLE QUOTATION MARK
# Appearances: 2
#
# Character: RIGHT DOUBLE QUOTATION MARK
# Appearances: 10
#
# Character: BULLET
# Appearances: 2
#
# Character: DOUBLE PRIME
# Appearances: 1
#
# Character: FRACTION SLASH
# Appearances: 43
#
# Character: TRADE MARK SIGN
# Appearances: 1
#
# Character: VULGAR FRACTION ONE THIRD
# Appearances: 70
#
# Character: VULGAR FRACTION TWO THIRDS
# Appearances: 18
#
# Character: VULGAR FRACTION ONE EIGHTH
# Appearances: 8
#
# Character: VULGAR FRACTION THREE EIGHTHS
# Appearances: 1
#
# Character: VULGAR FRACTION SEVEN EIGHTHS
# Appearances: 1
#
# Character: LATIN SMALL LIGATURE FF
# Appearances: 1
#
# Character: LATIN SMALL LIGATURE FI
# Appearances: 5
#
# Character: LATIN SMALL LIGATURE FL
# Appearances: 4
#
# Character: REPLACEMENT CHARACTER
# Appearances: 1

# %% [markdown]
# #### Instructions analysis

# %%
# Analyze strings
lengths = info['Instructions'].str.len()
print("Instructions lengths:")
print(f"Longest instructions: {max(lengths)} characters.")
print(f"Shortest instructions: {min(lengths)} characters.")
print(f"Mean instructions length: {round(np.mean(lengths),2)} characters.")
print(f"Standard Deviation of instructions lengths: {round(np.std(lengths),2)} characters.")
# Out:
# Instructions lengths:
# Longest instructions: 13952 characters.
# Shortest instructions: 40 characters.
# Mean instructions length: 1040.61 characters.
# Standard Deviation of instructions lengths: 711.15 characters.

# %%
# Analyze characters
look_char(info, 'Instructions')
# Out:
# Unique characters: 174
#
#  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]_`abcdefghijklmnopqrstuvwxyz{|}¡§¬­®°±³´¹º»¼½¾¿ÁÉÑ×àáâäåçèéêëìíîïñóôõöùúûüÿōˆ˚́̊​‐‑–—‘’‚“”‟•…″⁄⅓⅔⅛⅜−◊ﬀﬁﬂ�
#
# Character: <control>
# Appearances: 11875
#
# Character: <control>
# Appearances: 1
#
# Character: SPACE
# Appearances: 13463
#
# Character: EXCLAMATION MARK
# Appearances: 209
#
# Character: QUOTATION MARK
# Appearances: 1567
#
# Character: NUMBER SIGN
# Appearances: 15
#
# Character: DOLLAR SIGN
# Appearances: 66
#
# Character: PERCENT SIGN
# Appearances: 15
#
# Character: AMPERSAND
# Appearances: 41
#
# Character: APOSTROPHE
# Appearances: 1404
#
# Character: LEFT PARENTHESIS
# Appearances: 6955
#
# Character: RIGHT PARENTHESIS
# Appearances: 6955
#
# Character: ASTERISK
# Appearances: 348
#
# Character: PLUS SIGN
# Appearances: 12
#
# Character: COMMA
# Appearances: 13230
#
# Character: HYPHEN-MINUS
# Appearances: 10037
#
# Character: FULL STOP
# Appearances: 13454
#
# Character: SOLIDUS
# Appearances: 7574
#
# Character: DIGIT ZERO
# Appearances: 9205
#
# Character: DIGIT ONE
# Appearances: 11852
#
# Character: DIGIT TWO
# Appearances: 11166
#
# Character: DIGIT THREE
# Appearances: 9689
#
# Character: DIGIT FOUR
# Appearances: 8888
#
# Character: DIGIT FIVE
# Appearances: 9378
#
# Character: DIGIT SIX
# Appearances: 4009
#
# Character: DIGIT SEVEN
# Appearances: 2613
#
# Character: DIGIT EIGHT
# Appearances: 4382
#
# Character: DIGIT NINE
# Appearances: 1508
#
# Character: COLON
# Appearances: 2312
#
# Character: SEMICOLON
# Appearances: 7167
#
# Character: LESS-THAN SIGN
# Appearances: 16
#
# Character: EQUALS SIGN
# Appearances: 4
#
# Character: GREATER-THAN SIGN
# Appearances: 19
#
# Character: QUESTION MARK
# Appearances: 34
#
# Character: COMMERCIAL AT
# Appearances: 1
#
# Character: LATIN CAPITAL LETTER A
# Appearances: 9643
#
# Character: LATIN CAPITAL LETTER B
# Appearances: 6930
#
# Character: LATIN CAPITAL LETTER C
# Appearances: 9768
#
# Character: LATIN CAPITAL LETTER D
# Appearances: 6820
#
# Character: LATIN CAPITAL LETTER E
# Appearances: 1866
#
# Character: LATIN CAPITAL LETTER F
# Appearances: 7262
#
# Character: LATIN CAPITAL LETTER G
# Appearances: 3388
#
# Character: LATIN CAPITAL LETTER H
# Appearances: 5220
#
# Character: LATIN CAPITAL LETTER I
# Appearances: 4257
#
# Character: LATIN CAPITAL LETTER J
# Appearances: 408
#
# Character: LATIN CAPITAL LETTER K
# Appearances: 1019
#
# Character: LATIN CAPITAL LETTER L
# Appearances: 5468
#
# Character: LATIN CAPITAL LETTER M
# Appearances: 5506
#
# Character: LATIN CAPITAL LETTER N
# Appearances: 391
#
# Character: LATIN CAPITAL LETTER O
# Appearances: 2591
#
# Character: LATIN CAPITAL LETTER P
# Appearances: 9844
#
# Character: LATIN CAPITAL LETTER Q
# Appearances: 165
#
# Character: LATIN CAPITAL LETTER R
# Appearances: 7648
#
# Character: LATIN CAPITAL LETTER S
# Appearances: 11344
#
# Character: LATIN CAPITAL LETTER T
# Appearances: 9493
#
# Character: LATIN CAPITAL LETTER U
# Appearances: 3404
#
# Character: LATIN CAPITAL LETTER V
# Appearances: 316
#
# Character: LATIN CAPITAL LETTER W
# Appearances: 5929
#
# Character: LATIN CAPITAL LETTER X
# Appearances: 69
#
# Character: LATIN CAPITAL LETTER Y
# Appearances: 618
#
# Character: LATIN CAPITAL LETTER Z
# Appearances: 40
#
# Character: LEFT SQUARE BRACKET
# Appearances: 18
#
# Character: REVERSE SOLIDUS
# Appearances: 1
#
# Character: RIGHT SQUARE BRACKET
# Appearances: 18
#
# Character: LOW LINE
# Appearances: 7
#
# Character: GRAVE ACCENT
# Appearances: 1
#
# Character: LATIN SMALL LETTER A
# Appearances: 13463
#
# Character: LATIN SMALL LETTER B
# Appearances: 13377
#
# Character: LATIN SMALL LETTER C
# Appearances: 13429
#
# Character: LATIN SMALL LETTER D
# Appearances: 13460
#
# Character: LATIN SMALL LETTER E
# Appearances: 13463
#
# Character: LATIN SMALL LETTER F
# Appearances: 13141
#
# Character: LATIN SMALL LETTER G
# Appearances: 13430
#
# Character: LATIN SMALL LETTER H
# Appearances: 13451
#
# Character: LATIN SMALL LETTER I
# Appearances: 13462
#
# Character: LATIN SMALL LETTER J
# Appearances: 7653
#
# Character: LATIN SMALL LETTER K
# Appearances: 12986
#
# Character: LATIN SMALL LETTER L
# Appearances: 13461
#
# Character: LATIN SMALL LETTER M
# Appearances: 13415
#
# Character: LATIN SMALL LETTER N
# Appearances: 13463
#
# Character: LATIN SMALL LETTER O
# Appearances: 13461
#
# Character: LATIN SMALL LETTER P
# Appearances: 13334
#
# Character: LATIN SMALL LETTER Q
# Appearances: 5789
#
# Character: LATIN SMALL LETTER R
# Appearances: 13463
#
# Character: LATIN SMALL LETTER S
# Appearances: 13461
#
# Character: LATIN SMALL LETTER T
# Appearances: 13462
#
# Character: LATIN SMALL LETTER U
# Appearances: 13419
#
# Character: LATIN SMALL LETTER V
# Appearances: 13187
#
# Character: LATIN SMALL LETTER W
# Appearances: 13368
#
# Character: LATIN SMALL LETTER X
# Appearances: 8778
#
# Character: LATIN SMALL LETTER Y
# Appearances: 12899
#
# Character: LATIN SMALL LETTER Z
# Appearances: 6259
#
# Character: LEFT CURLY BRACKET
# Appearances: 4
#
# Character: VERTICAL LINE
# Appearances: 2
#
# Character: RIGHT CURLY BRACKET
# Appearances: 4
#
# Character: <control>
# Appearances: 7
#
# Character: <control>
# Appearances: 3
#
# Character: <control>
# Appearances: 1
#
# Character: <control>
# Appearances: 1
#
# Character: <control>
# Appearances: 1
#
# Character: INVERTED EXCLAMATION MARK
# Appearances: 1
#
# Character: SECTION SIGN
# Appearances: 1
#
# Character: NOT SIGN
# Appearances: 4
#
# Character: SOFT HYPHEN
# Appearances: 5
#
# Character: REGISTERED SIGN
# Appearances: 3
#
# Character: DEGREE SIGN
# Appearances: 5905
#
# Character: PLUS-MINUS SIGN
# Appearances: 1
#
# Character: SUPERSCRIPT THREE
# Appearances: 1
#
# Character: ACUTE ACCENT
# Appearances: 2
#
# Character: SUPERSCRIPT ONE
# Appearances: 1
#
# Character: MASCULINE ORDINAL INDICATOR
# Appearances: 68
#
# Character: RIGHT-POINTING DOUBLE ANGLE QUOTATION MARK
# Appearances: 3
#
# Character: VULGAR FRACTION ONE QUARTER
# Appearances: 130
#
# Character: VULGAR FRACTION ONE HALF
# Appearances: 189
#
# Character: VULGAR FRACTION THREE QUARTERS
# Appearances: 44
#
# Character: INVERTED QUESTION MARK
# Appearances: 3
#
# Character: LATIN CAPITAL LETTER A WITH ACUTE
# Appearances: 1
#
# Character: LATIN CAPITAL LETTER E WITH ACUTE
# Appearances: 3
#
# Character: LATIN CAPITAL LETTER N WITH TILDE
# Appearances: 1
#
# Character: MULTIPLICATION SIGN
# Appearances: 16
#
# Character: LATIN SMALL LETTER A WITH GRAVE
# Appearances: 12
#
# Character: LATIN SMALL LETTER A WITH ACUTE
# Appearances: 30
#
# Character: LATIN SMALL LETTER A WITH CIRCUMFLEX
# Appearances: 32
#
# Character: LATIN SMALL LETTER A WITH DIAERESIS
# Appearances: 4
#
# Character: LATIN SMALL LETTER A WITH RING ABOVE
# Appearances: 1
#
# Character: LATIN SMALL LETTER C WITH CEDILLA
# Appearances: 9
#
# Character: LATIN SMALL LETTER E WITH GRAVE
# Appearances: 305
#
# Character: LATIN SMALL LETTER E WITH ACUTE
# Appearances: 2305
#
# Character: LATIN SMALL LETTER E WITH CIRCUMFLEX
# Appearances: 13
#
# Character: LATIN SMALL LETTER E WITH DIAERESIS
# Appearances: 2
#
# Character: LATIN SMALL LETTER I WITH GRAVE
# Appearances: 2
#
# Character: LATIN SMALL LETTER I WITH ACUTE
# Appearances: 11
#
# Character: LATIN SMALL LETTER I WITH CIRCUMFLEX
# Appearances: 209
#
# Character: LATIN SMALL LETTER I WITH DIAERESIS
# Appearances: 3
#
# Character: LATIN SMALL LETTER N WITH TILDE
# Appearances: 276
#
# Character: LATIN SMALL LETTER O WITH ACUTE
# Appearances: 25
#
# Character: LATIN SMALL LETTER O WITH CIRCUMFLEX
# Appearances: 3
#
# Character: LATIN SMALL LETTER O WITH TILDE
# Appearances: 1
#
# Character: LATIN SMALL LETTER O WITH DIAERESIS
# Appearances: 5
#
# Character: LATIN SMALL LETTER U WITH GRAVE
# Appearances: 24
#
# Character: LATIN SMALL LETTER U WITH ACUTE
# Appearances: 6
#
# Character: LATIN SMALL LETTER U WITH CIRCUMFLEX
# Appearances: 13
#
# Character: LATIN SMALL LETTER U WITH DIAERESIS
# Appearances: 11
#
# Character: LATIN SMALL LETTER Y WITH DIAERESIS
# Appearances: 1
#
# Character: LATIN SMALL LETTER O WITH MACRON
# Appearances: 1
#
# Character: MODIFIER LETTER CIRCUMFLEX ACCENT
# Appearances: 1
#
# Character: RING ABOVE
# Appearances: 28
#
# Character: COMBINING ACUTE ACCENT
# Appearances: 6
#
# Character: COMBINING RING ABOVE
# Appearances: 1
#
# Character: ZERO WIDTH SPACE
# Appearances: 2
#
# Character: HYPHEN
# Appearances: 2
#
# Character: NON-BREAKING HYPHEN
# Appearances: 3
#
# Character: EN DASH
# Appearances: 2239
#
# Character: EM DASH
# Appearances: 456
#
# Character: LEFT SINGLE QUOTATION MARK
# Appearances: 2
#
# Character: RIGHT SINGLE QUOTATION MARK
# Appearances: 694
#
# Character: SINGLE LOW-9 QUOTATION MARK
# Appearances: 4
#
# Character: LEFT DOUBLE QUOTATION MARK
# Appearances: 53
#
# Character: RIGHT DOUBLE QUOTATION MARK
# Appearances: 78
#
# Character: DOUBLE HIGH-REVERSED-9 QUOTATION MARK
# Appearances: 1
#
# Character: BULLET
# Appearances: 22
#
# Character: HORIZONTAL ELLIPSIS
# Appearances: 3
#
# Character: DOUBLE PRIME
# Appearances: 1
#
# Character: FRACTION SLASH
# Appearances: 19
#
# Character: VULGAR FRACTION ONE THIRD
# Appearances: 24
#
# Character: VULGAR FRACTION TWO THIRDS
# Appearances: 7
#
# Character: VULGAR FRACTION ONE EIGHTH
# Appearances: 15
#
# Character: VULGAR FRACTION THREE EIGHTHS
# Appearances: 1
#
# Character: MINUS SIGN
# Appearances: 3
#
# Character: LOZENGE
# Appearances: 3
#
# Character: LATIN SMALL LIGATURE FF
# Appearances: 1
#
# Character: LATIN SMALL LIGATURE FI
# Appearances: 2
#
# Character: LATIN SMALL LIGATURE FL
# Appearances: 4
#
# Character: REPLACEMENT CHARACTER
# Appearances: 1
